# %% [markdown]
# # Appendix to “Analysing decisions in data analysis”
#
# H. Sherry Zhang (University of Texas at Austin)
# Roger D. Peng (University of Texas at Austin)
#
# # LLM prompt used to obtain the decision database
